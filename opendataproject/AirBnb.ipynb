# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
airbnb_data = pd.read_csv("listings.csv")

# %% [markdown]
# # Data from Airbnb

# %%
airbnb_data.head()
# Out:
#          id                                              name    host_id  \
# 0  16194102  Large townhouse in Warriewood near Beach & shops   50355584
# 1  16231561                    Modern,  clean  &  comfortable  101457989
# 2  15526112       Bright Beachside house minutes to the beach   51175994
# 3   4849322                Do you enjoy a beaches lifestyle 2    5409864
# 4  11537464                                 Rooms With A View   60462412
#
#          host_name  neighbourhood_group neighbourhood   latitude   longitude  \
# 0            Karen                  NaN     Pittwater -33.680820  151.286877
# 1  David & Claudia                  NaN     Pittwater -33.706076  151.295526
# 2           Jaycie                  NaN     Pittwater -33.699979  151.307498
# 3            Annie                  NaN     Pittwater -33.679562  151.291916
# 4              Mel                  NaN     Pittwater -33.705918  151.297098
#
# ...

# %%
airbnb_data.shape
# Out:
# (24038, 16)

# %%
airbnb_data.columns
# Out:
# Index([u'id', u'name', u'host_id', u'host_name', u'neighbourhood_group',
#        u'neighbourhood', u'latitude', u'longitude', u'room_type', u'price',
#        u'minimum_nights', u'number_of_reviews', u'last_review',
#        u'reviews_per_month', u'calculated_host_listings_count',
#        u'availability_365'],
#       dtype='object')

# %%
row_one_data = airbnb_data.iloc[1]
row_one_data
# Out:
# id                                                      16231561
# name                              Modern,  clean  &  comfortable
# host_id                                                101457989
# host_name                                        David & Claudia
# neighbourhood_group                                          NaN
# neighbourhood                                          Pittwater
# latitude                                                -33.7061
# longitude                                                151.296
# room_type                                        Entire home/apt
# price                                                         95
# minimum_nights                                                 1
# number_of_reviews                                             19
# last_review                                           2017-02-25
# reviews_per_month                                           4.87
# ...

# %%
row_two = airbnb_data.iloc[2]
row_two
# Out:
# id                                                                   15526112
# name                              Bright Beachside house minutes to the beach
# host_id                                                              51175994
# host_name                                                              Jaycie
# neighbourhood_group                                                       NaN
# neighbourhood                                                       Pittwater
# latitude                                                                -33.7
# longitude                                                             151.307
# room_type                                                     Entire home/apt
# price                                                                     300
# minimum_nights                                                              2
# number_of_reviews                                                           4
# ...

# %%
airbnb_data["id"].plot(kind="bar")
plt.title("Case IDs", fontsize=26)
plt.xlabel("Case", fontsize=26)
plt.ylabel("ID", fontsize=26)

# %%
airbnb_data["host_id"].plot(kind="bar")
plt.title("AirBnb Host Id Numbers", fontsize=26)
plt.xlabel("Host", fontsize=26)
plt.ylabel("ID", fontsize=26)

# %%
airbnb_data["host_name"].value_counts().plot(kind="bar")
plt.title("Host Names", fontsize=26)
plt.xlabel("Name", fontsize=26)
plt.ylabel("Property Owned", fontsize=26)

# %%
name_counts = airbnb_data["host_name"].value_counts()
name_counts[name_counts > 10].plot(kind="bar")
plt.title("Host Names", fontsize=26)
plt.xlabel("Name", fontsize=26)
plt.ylabel("Property Owned", fontsize=26)

# %%
name_counts[name_counts > 50].plot(kind="bar", grid=True)
plt.title("Host Names", fontsize=26)
plt.xlabel("Name", fontsize=26)
plt.ylabel("Property Owned", fontsize=26)

# %%
airbnb_data["neighbourhood"].value_counts().plot(kind="barh", grid=True)
plt.title("Neighbourhoods the Properties are Located", fontsize=26)
plt.xlabel("Properties", fontsize=26)
plt.ylabel("Cities/Suburbs", fontsize=26)

# %%
airbnb_data["latitude"].hist()
plt.title("Latitude of Accommodations", fontsize=26)
plt.xlabel("Latitudinal Value", fontsize=26)
plt.ylabel("Property Number", fontsize=26)

# %%
airbnb_data["longitude"].hist()
plt.title("Longitude of Accommodations", fontsize=26)
plt.xlabel("Longitudinal Value", fontsize=26)
plt.ylabel("Property Number", fontsize=26)

# %%
airbnb_data["room_type"].value_counts().plot(kind="pie")
plt.title("Types of Rooms offered by Airbnb", fontsize=26)
plt.ylabel("", fontsize=26)

# %%
price_bar = airbnb_data["price"].value_counts()
price_bar[price_bar < 4000].plot(kind="bar")
plt.title("Prices per Night", fontsize=26)
plt.xlabel("Prices in $", fontsize=26)
plt.ylabel("No. of Properties Available", fontsize=26)

# %%
price_bar = airbnb_data["price"].value_counts()
price_bar[price_bar < 100].plot(kind="bar")
plt.title("Prices per Night", fontsize=26)
plt.xlabel("Prices in $", fontsize=26)
plt.ylabel("No. of Properties Available", fontsize=26)

# %%
price_bar = airbnb_data["price"].value_counts()
price_bar[price_bar > 100].plot(kind="bar", grid=True)
plt.title("Prices per Night", fontsize=26)
plt.xlabel("Prices in $", fontsize=26)
plt.ylabel("No. of Properties Available", fontsize=26)

# %%
price_bar = airbnb_data["price"].value_counts()
price_bar[price_bar > 500].plot(kind="bar", grid=True)
plt.title("Prices per Night", fontsize=26)
plt.xlabel("Prices in $", fontsize=26)
plt.ylabel("No. of Properties Available", fontsize=26)
