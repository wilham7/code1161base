# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.plotly as py
import scipy as sp
import os 
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print __version__ # requires version >= 1.9.0
# Out:
# 2.0.9

# %%
from plotly.graph_objs import Scatter, Figure, Layout

plot([Scatter(x=[1, 2, 3], y=[3, 1, 6])])
# Out:
# 'file:///home/eden/code1161base/dataset/temp-plot.html'

# %%
# %matplotlib inline

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

absmag = hyg_data['absmag']()
mag = hyg_data['mag']()

# Create a trace
trace = go.Scatter(
    x = absmag,
    y = mag,
    mode = 'markers'
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data, filename='basic-scatter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a35060d3ead7> in <module>()
#       2 import plotly.graph_objs as go
#       3
# ----> 4 absmag = hyg_data['absmag']()
#       5 mag = hyg_data['mag']()
#       6
#
# NameError: name 'hyg_data' is not defined

# %%
import plotly 
plotly.tools.set_credentials_file(username='azasibi', api_key='4ECEozhbsoIFu2rrgxEw')

# %%
import plotly.plotly as py
from plotly.graph_objs import *

import numpy as np

s = np.linspace(0, 2 * np.pi, 240)
t = np.linspace(0, np.pi, 240)
tGrid, sGrid = np.meshgrid(s, t)

r = 2 + np.sin(7 * sGrid + 5 * tGrid)  # r = 2 + sin(7s+5t)
x = r * np.cos(sGrid) * np.sin(tGrid)  # x = r*cos(s)*sin(t)
y = r * np.sin(sGrid) * np.sin(tGrid)  # y = r*sin(s)*sin(t)
z = r * np.cos(tGrid)                  # z = r*cos(t)

surface = Surface(x=x, y=y, z=z)
data = Data([surface])

layout = Layout(
    title='Parametric Plot',
    scene=Scene(
        xaxis=XAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        yaxis=YAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        zaxis=ZAxis(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        )
    )
)

fig = Figure(data=data, layout=layout)
py.iplot(fig, filename='jupyter/parametric_plot')
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-12-cac27b6fdcee> in <module>()
#      41
#      42 fig = Figure(data=data, layout=layout)
# ---> 43 py.iplot(fig, filename='jupyter/parametric_plot')
#
# /usr/local/lib/python2.7/dist-packages/plotly/plotly/plotly.pyc in iplot(figure_or_data, **plot_options)
#     132     if 'auto_open' not in plot_options:
#     133         plot_options['auto_open'] = False
# --> 134     url = plot(figure_or_data, **plot_options)
#     135
#     136     if isinstance(figure_or_data, dict):
#
# /usr/local/lib/python2.7/dist-packages/plotly/plotly/plotly.pyc in plot(figure_or_data, validate, **plot_options)
#     225     data = fig.get('data', [])
#     226     plot_options['layout'] = fig.get('layout', {})
# --> 227     response = v1.clientresp(data, **plot_options)
#     228
#     229     # Check if the url needs a secret key
#
# /usr/local/lib/python2.7/dist-packages/plotly/api/v1/clientresp.pyc in clientresp(data, **kwargs)
#      33
#      34     url = '{plotly_domain}/clientresp'.format(**cfg)
# ---> 35     response = request('post', url, data=payload)
#      36
#      37     # Old functionality, just keeping it around.
#
# /usr/local/lib/python2.7/dist-packages/plotly/api/v1/utils.pyc in request(method, url, **kwargs)
#      84         content = response.content if response else 'No content'
#      85         raise exceptions.PlotlyRequestError(message, status_code, content)
# ---> 86     validate_response(response)
#      87     return response
#
# /usr/local/lib/python2.7/dist-packages/plotly/api/v1/utils.pyc in validate_response(response)
#      36         message = content if content else 'No Content'
#      37
# ---> 38     raise exceptions.PlotlyRequestError(message, status_code, content)
#      39
#      40
#
# PlotlyRequestError: Hi there! Free users cannot create folders.
#
# To save this file on Plotly, please remove the folder in your filename path.
#
# If you would like to create folders and save files in them, please upgrade your account at: https://goo.gl/NrPpg6

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20,10)

# %%
filepath = "hygdata_v3.csv"
hyg_data = pd.read_csv(filepath)
print "done"

hyg_data.head()
# Out:
# done
#    id  hip        hd  hr   gl   bf proper        ra        dec      dist  \
# 0   0  NaN       NaN NaN  NaN  NaN    Sol  0.000000   0.000000    0.0000
# 1   1  1.0  224700.0 NaN  NaN  NaN    NaN  0.000060   1.089009  219.7802
# 2   2  2.0  224690.0 NaN  NaN  NaN    NaN  0.000283 -19.498840   47.9616
# 3   3  3.0  224699.0 NaN  NaN  NaN    NaN  0.000335  38.859279  442.4779
# 4   4  4.0  224707.0 NaN  NaN  NaN    NaN  0.000569 -51.893546  134.2282
#
#     ...     bayer  flam  con  comp  comp_primary base         lum  var  \
# 0   ...       NaN   NaN  NaN     1             0  NaN    1.000000  NaN
# 1   ...       NaN   NaN  Psc     1             1  NaN    9.638290  NaN
# 2   ...       NaN   NaN  Cet     1             2  NaN    0.392283  NaN
# 3   ...       NaN   NaN  And     1             3  NaN  386.901132  NaN
# 4   ...       NaN   NaN  Phe     1             4  NaN    9.366989  NaN
#
#    var_min  var_max
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 37 columns]

# %%
hyg_data.columns
# Out:
# Index([u'id', u'hip', u'hd', u'hr', u'gl', u'bf', u'proper', u'ra', u'dec',
#        u'dist', u'pmra', u'pmdec', u'rv', u'mag', u'absmag', u'spect', u'ci',
#        u'x', u'y', u'z', u'vx', u'vy', u'vz', u'rarad', u'decrad', u'pmrarad',
#        u'pmdecrad', u'bayer', u'flam', u'con', u'comp', u'comp_primary',
#        u'base', u'lum', u'var', u'var_min', u'var_max'],
#       dtype='object')

# %%
row_one = hyg_data.iloc[1]
row_one
# Out:
# id                        1
# hip                       1
# hd                   224700
# hr                      NaN
# gl                      NaN
# bf                      NaN
# proper                  NaN
# ra                    6e-05
# dec                 1.08901
# dist                 219.78
# pmra                   -5.2
# pmdec                 -1.88
# rv                        0
# mag                     9.1
# absmag                 2.39
# spect                    F5
# ci                    0.482
# x                   219.741
# y                  0.003449
# z                   4.17706
# vx                    4e-08
# vy                -5.54e-06
# vz                   -2e-06
# rarad           1.56934e-05
# decrad            0.0190068
# pmrarad        -2.52103e-08
# pmdecrad        -9.1145e-09
# bayer                   NaN
# flam                    NaN
# con                     Psc
# comp                      1
# comp_primary              1
# base                    NaN
# lum                 9.63829
# var                     NaN
# var_min                 NaN
# var_max                 NaN
# Name: 1, dtype: object

# %%
row_one["var_max"]
# Out:
# nan

# %%
hyg_data["var_max"]
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6         12.162
# 7            NaN
# 8          7.648
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17        11.543
# 18        10.948
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
#            ...
# 119584       NaN
# 119585       NaN
# 119586       NaN
# 119587       NaN
# 119588       NaN
# 119589       NaN
# 119590       NaN
# 119591       NaN
# 119592       NaN
# 119593       NaN
# 119594       NaN
# 119595       NaN
# 119596       NaN
# 119597       NaN
# 119598       NaN
# 119599       NaN
# 119600       NaN
# 119601       NaN
# 119602       NaN
# 119603       NaN
# 119604       NaN
# 119605       NaN
# 119606       NaN
# 119607       NaN
# 119608       NaN
# 119609       NaN
# 119610       NaN
# 119611       NaN
# 119612       NaN
# 119613       NaN
# Name: var_max, Length: 119614, dtype: float64

# %%
hyg_data["var_max"].plot()

# %%
hyg_data["var_max"].hist()

# %%
hyg_data["var_max"][hyg_data["var_max"] < 10].hist()

# %%
some_numbers = pd.Series(range(10))
some_numbers.head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
some_numbers[some_numbers < 3]
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
some_numbers[(some_numbers < 4) | (some_numbers > 97)]
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
hyg_data["absmag"].value_counts()
# Out:
# -11.030    71
# -11.040    59
# -10.900    58
# -10.940    58
# -11.150    58
# -11.110    56
# -11.190    56
# -10.850    56
# -10.950    55
# -11.010    54
# -11.310    54
# -11.020    53
# -11.090    52
# -11.200    52
# -10.820    52
# -10.730    52
# -10.980    51
# -11.280    51
# -10.930    50
# -11.320    50
# -10.990    50
# -10.970    50
# -11.060    49
# -11.140    48
# -10.880    48
# -11.170    48
# -11.380    47
# -11.130    47
# -10.650    47
# -11.100    47
#            ..
#  12.480     1
#  15.642     1
#  13.336     1
#  11.362     1
# -2.567      1
#  8.402      1
# -2.345      1
#  9.207      1
# -3.751      1
# -15.750     1
#  13.887     1
#  8.373      1
#  9.911      1
#  9.326      1
#  14.577     1
#  11.625     1
# -15.000     1
# -2.856      1
# -4.166      1
#  10.870     1
#  5.917      1
#  10.432     1
# -3.547      1
#  8.255      1
#  12.063     1
# -2.670      1
# -2.740      1
#  14.628     1
#  6.999      1
#  14.333     1
# Name: absmag, Length: 13451, dtype: int64

# %%
hyg_data["absmag"].value_counts(200).plot(kind="bar")

# %%
magdata=hyg_data.sample(1000)
magdata.mag.plot(kind="bar")

# %%
display=hyg_data.sample(1000)
display.absmag.plot(kind="bar")

# %%
sample200=hyg_data.sample(200)
sample200.absmag.plot(kind="bar")

# %%
vismag200=hyg_data.sample(200)
vismag200.mag.plot(kind="bar")

# %%
print"M=m-5(log10(d/10))"
# Out:
# M=m-5(log10(d/10))

# %%
trialtable = hyg_data[['absmag', 'mag', 'dist']].sample(200)
trialtable.head()
# Out:
#        absmag   mag         dist
# 32038   0.609  8.05     307.6923
# 16646   2.234  8.92     217.3913
# 2451  -10.580  9.42  100000.0000
# 90259   5.421  8.33      38.1825
# 38447   0.280  8.69     480.7692

# %%
filepath = "hygdata_v3.csv"
hyg_data = pd.read_csv(filepath)

# %%
absmaggroup = hyg_data.groupby('absmag')
absmaggroup.size()
# Out:
# absmag
# -16.680    1
# -16.230    1
# -16.160    2
# -16.110    1
# -16.070    1
# -16.060    1
# -15.830    1
# -15.770    1
# -15.750    1
# -15.740    1
# -15.530    1
# -15.490    1
# -15.410    1
# -15.350    1
# -15.290    1
# -15.270    1
# -15.240    1
# -15.230    1
# -15.170    1
# -15.140    1
# -15.120    1
# -15.080    1
# -15.050    1
# -15.020    1
# -15.010    1
# -15.000    1
# -14.960    2
# -14.930    1
# -14.910    1
# -14.900    1
#           ..
#  16.317    1
#  16.327    1
#  16.329    1
#  16.391    1
#  16.527    1
#  16.557    1
#  16.631    1
#  16.666    1
#  16.676    1
#  16.728    1
#  16.957    1
#  16.969    1
#  17.013    1
#  17.134    1
#  17.163    1
#  17.169    1
#  17.189    1
#  17.322    1
#  17.480    1
#  17.491    1
#  17.835    1
#  17.951    1
#  17.986    1
#  18.084    1
#  18.676    1
#  18.802    1
#  18.994    1
#  19.137    1
#  19.237    1
#  19.629    1
# Length: 13451, dtype: int64

# %%
from plotly.graph_objs import *

absmag = hyg_data.sort(columns='absmag',ascending =False).plot(kind='bar',legend=None,title="absolute magnitude of stars").sample(200)
absmag.set_xlabel('star id')
absmag.set_ylabel('Absolute magnitudes')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-5022b5a0b75e> in <module>()
#       1 from plotly.graph_objs import *
#       2
# ----> 3 absmag = hyg_data.sort(columns='absmag',ascending =False).plot(kind='bar',legend=None,title="absolute magnitude of stars").sample(200)
#       4 absmag.set_xlabel('star id')
#       5 absmag.set_ylabel('Absolute magnitudes')
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
complines = hyg_data["absmag"].value_counts()
complines[complines < 1000].plot(kind="line")

# %%
capped_face_value_data = hyg_data["absmag"][hyg_data["absmag"] < 1000]

plt.hist(capped_face_value_data, bins=10, facecolor='blue', alpha=0.2) #<-old one
plt.hist(capped_face_value_data, bins=50, facecolor='green', alpha=1)  #<-new one
plt.show()
